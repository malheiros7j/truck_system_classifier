# %% [markdown]
# # Case Técnico BIX: Consultoria de dados para uma empresa terceirizada de transporte de caminhões.

# %% [markdown]
# ## Planejamento da Solução

# %% [markdown]
# ### Entrada

# %% [markdown]
# #### Entendimento de Negócio

# %% [markdown]
# **Qual é o problema de negócio?**
#
# * Uma empresa terceirizada de transporte de caminhões deseja diminuir os gastos de manutenção dos sistemas de ar de sua frota de veículos. Foi observado que o valor gasto com esse sistema vem crescendo ao longo dos últimos anos mesmo mantendo o tamanho de sua frota constante. Para resolver esse problema, podemos fazer a seguinte análise:
#
#     1. Realizar a classificação do sistema de ar de caminhões baseado em suas características fornecidas pelos dados do setor de manutenção e assim reduzir os gastos com esse sistema ao longo dos anos.
#     2. Analisar quais são as variáveis que influenciam esse problema no sistema de ar da frota de caminhões.

# %% [markdown]
# ### Saída

# %% [markdown]
# * Qual o formato de entrega da solução ?
#
#     - Jupyter Notebooks, onde o projeto foi desenvolvido por meio de ciclos, com objetivo de gerenciar e planejar os próximos passos e manter uma entrega contínua de valor para a empresa. As respostas dos problemas de negócio podem ser encontradas no último notebook do ciclo do projeto (ciclo04_FINAL).
#
#     - Modelo em produção com API no Render e disponível por meio de uma planilha no Google Spreadsheets, onde foi criado um script para a realização da classificação dos sistemas de ar. O endereço da planilha Google SpreadSheet está localizado na página do repositório.
#
#     - Documento em formato PDF com as respostas referentes às perguntas do desafio.

# %% [markdown]
# ### Metodologia
# - CRISP-DM, metodologia ágil para desenvolvimento de projetos de ciência de dados ( método cíclico ).
# - Abordagem de classificação.

# %% [markdown]
# ### Ferramentas Utilizadas
# Python 3.10.6, Jupyter-Lab, Git, Github, Poetry.

# %% [markdown]
# ## Implementações Realizadas na Sprint

# %% [markdown]
# ### Ciclo 2

# %% [markdown]
# * Padronização dos Dados usando Standart Scaling.
# * Testar outros modelos de Classificação.
# * Implementação de Cross_Validation.
# * Definição das métricas de perfomance do modelo.

# %% [markdown]
# # 0.0 Imports

# %%
import pandas as pd
import numpy as np
import seaborn as sns

from matplotlib import pyplot as plt
from IPython.core.display import HTML


from sklearn.metrics import accuracy_score, recall_score, confusion_matrix, ConfusionMatrixDisplay,precision_score,f1_score, average_precision_score, roc_auc_score,precision_recall_curve, PrecisionRecallDisplay

from sklearn import preprocessing as pp
from sklearn import model_selection as ms
from sklearn.model_selection import StratifiedKFold
from sklearn.neighbors       import KNeighborsClassifier
from sklearn.linear_model    import LogisticRegression
from sklearn.ensemble        import RandomForestClassifier, ExtraTreesClassifier, RandomForestClassifier

from lightgbm                import LGBMClassifier
from xgboost                 import XGBClassifier

# %% [markdown]
# # 0.1 Auxiliar Functions

# %%
def jupyter_settings():
    # %matplotlib inline
    #%pylab inline
    
    plt.style.use('bmh')
    plt.rcParams['figure.figsize'] = [25,12]
    plt.rcParams['font.size'] = 24
    
    display(HTML ('<style>.container {width:100% !important;} </style>') )
    pd.options.display.max_columns=None
    pd.options.display.max_rows = None
    pd.set_option('display.expand_frame_repr',False)
    pd.set_option('display.float_format', lambda x: '%.4f' % x)
    
    sns.set()
    
jupyter_settings()

def cross_validation(model, x_train, y_train, k, Verbose=True):
    
    kfold = StratifiedKFold(n_splits=k,shuffle=True,random_state=42)
    
    recall_list = []
    f1_score_list = []
    roc_auc_list = []
    auc_pr_list = []
    i = 1
    
    for train_cv, val_cv in kfold.split(x_train,y_train):
        
        if Verbose == True:
            print(f'Fold Number {i}/{k}')
            
        else:
            pass
        
        x_train_fold = x_train.iloc[train_cv]
        y_train_fold = y_train.iloc[train_cv]
        
        x_val_fold = x_train.iloc[val_cv]
        y_val_fold = y_train.iloc[val_cv]
        
        model.fit(x_train_fold,y_train_fold)
        
        yhat_model = model.predict(x_val_fold)
        yhat_model_proba = model.predict_proba(x_val_fold)
        
        
        
        # Metrics 
        
        # Recall
        recall = recall_score(y_val_fold, yhat_model)
        recall_list.append(recall)
        
        # F1 Score
        f1score = f1_score(y_val_fold,yhat_model)
        f1_score_list.append(f1score)
        
        # ROC AUC
        roc_auc = roc_auc_score(y_val_fold,yhat_model_proba[:,1])
        roc_auc_list.append(roc_auc)
        
        # AUC PR
        auc_pr = average_precision_score(y_val_fold,yhat_model_proba[:,1])
        auc_pr_list.append(auc_pr)
        
        i+=1
        
    
    df = pd.DataFrame( {'Model Name': type(model).__name__,
                        'Recall': np.mean(recall_list),
                        'ROC AUC': np.mean(roc_auc_list),
                        'AUC PR': np.mean(auc_pr_list),
                        'F1 Score': np.mean(f1_score_list)},index=[0])
    
    return df


def classification_metrics(model,x_validation, y_validation):
        
    yhat = model.predict(x_validation)
    yhat_proba = model.predict_proba(x_validation)
        
    
    # Metrics 
    recall = recall_score(y_validation,yhat)
    
    # F1_Score
    f1score = f1_score(y_validation,yhat)
    
    # AUC SCORE
    roc_auc = roc_auc_score(y_validation, yhat_proba[:,1])
    
    # PRC AUC
    prc_auc = average_precision_score(y_validation, yhat_proba[:,1])
    
    # PLOT PRC 
    prec, recall_, _ = precision_recall_curve(y_validation, yhat, pos_label=model.classes_[1])
    pr_display = PrecisionRecallDisplay(precision=prec, recall=recall_).plot()
    
    cm = confusion_matrix(y_validation, yhat, labels=model.classes_)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=model.classes_)
    disp.plot()
    
    return pd.DataFrame({'Model_Name':type(model).__name__,
                         'Recall':recall,
                         'F1_Score':f1score,
                         'PRC AUC': prc_auc,
                         'AUC SCORE':roc_auc},index=[0])
# Out:
# <style>.container {width:100% !important;} </style>

# %% [markdown]
# # 0.2 Loading Data

# %%
df_raw_prev = pd.read_csv('../data/air_system_previous_years.csv')
df_raw_present =  pd.read_csv('../data/air_system_present_year.csv')

# %% [markdown]
# # 1.0 Data Description

# %%
df1 = df_raw_prev.copy()

# %% [markdown]
# ## 1.1 Data Columns

# %%
df1.columns
# Out:
# Index(['class', 'aa_000', 'ab_000', 'ac_000', 'ad_000', 'ae_000', 'af_000',
#        'ag_000', 'ag_001', 'ag_002',
#        ...
#        'ee_002', 'ee_003', 'ee_004', 'ee_005', 'ee_006', 'ee_007', 'ee_008',
#        'ee_009', 'ef_000', 'eg_000'],
#       dtype='object', length=171)

# %% [markdown]
# ## 1.2 Data Dimension

# %%
print('Formato do dataset: {} linhas e {} colunas'.format(df1.shape[0], df1.shape[1]))
# Out:
# Formato do dataset: 60000 linhas e 171 colunas

# %% [markdown]
# ## 1.3 Data Types

# %%
# df1.dtypes

# %% [markdown]
# Nessa etapa podemos observar que praticamente todas variáveis estão como tipo de objeto, portanto precisamos transformas elas do tipo numero visto que só possuí numeros como valores.

# %% [markdown]
# ## 1.4 Check NA / Types Transformation / Check Duplicated Rows

# %%
df1 = df1.replace('na',np.nan)

# %%
# Transform object features as float
df1 = df1.astype({col: float for col in df1.columns[1:]})

# %%
df1.head()
# Out:
#   class     aa_000  ab_000          ac_000   ad_000  ae_000  af_000  ag_000  ag_001  ag_002   ag_003     ag_004       ag_005       ag_006       ag_007     ag_008  ag_009       ah_000  ai_000   aj_000  ak_000   al_000      am_0       an_000       ao_000       ap_000       aq_000  ar_000  as_000  at_000  au_000    av_000   ax_000  ay_000  ay_001  ay_002  ay_003     ay_004      ay_005       ay_006       ay_007       ay_008  ay_009    az_000    az_001     az_002     az_003       az_004       az_005     az_006    az_007  az_008  az_009       ba_000       ba_001      ba_002      ba_003      ba_004      ba_005       ba_006      ba_007     ba_008    ba_009       bb_000   bc_000   bd_000   be_000   bf_000       bg_000     bh_000      bi_000      bj_000      bk_000      bl_000      bm_000      bn_000      bo_000  bp_000  bq_000  br_000      bs_000     bt_000       bu_000       bv_000       bx_000     by_000      bz_000      ca_000      cb_000       cc_000       cd_000      ce_000  cf_000   cg_000  ch_000       ci_000  cj_000      ck_000  cl_000    cm_000  cn_000  cn_001    cn_002      cn_003       cn_004       cn_005       cn_006     cn_007     cn_008    cn_009   co_000   cp_000       cq_000  cr_000     cs_000    cs_001      cs_002      cs_003      cs_004       cs_005       cs_006     cs_007   cs_008  cs_009    ct_000    cu_000       cv_000      cx_000  cy_000      cz_000  da_000  db_000       dc_000    dd_000    de_000  df_000  dg_000  dh_000  di_000  dj_000  dk_000  dl_000  dm_000     dn_000     do_000     dp_000    dq_000   dr_000      ds_000     dt_000        du_000       dv_000     dx_000     dy_000  dz_000  ea_000        eb_000     ec_00    ed_000      ee_000       ee_001       ee_002      ee_003      ee_004      ee_005      ee_006      ee_007      ee_008    ee_009  ef_000  eg_000
# 0   neg 76698.0000     NaN 2130706438.0000 280.0000  0.0000  0.0000  0.0000  0.0000  0.0000   0.0000 37250.0000 1432864.0000 3664156.0000 1007684.0000 25896.0000  0.0000 2551696.0000  0.0000   0.0000  0.0000   0.0000    0.0000 4933296.0000 3655166.0000 1766008.0000 1132040.0000  0.0000  0.0000  0.0000  0.0000 1012.0000 268.0000  0.0000  0.0000  0.0000  0.0000     0.0000 469014.0000 4239660.0000  703300.0000  755876.0000  0.0000 5374.0000 2108.0000  4114.0000 12348.0000  615248.0000 5526276.0000  2378.0000    4.0000  0.0000  0.0000 2328746.0000 1022304.0000 415432.0000 287230.0000 310246.0000 681504.0000 1118814.0000   3574.0000     0.
ba_005, ba_006, ba_007, ba_008, ba_009, bb_000, bc_000, bd_000, be_000, bf_000, bg_000, bh_000, bi_000, bj_000, bk_000, bl_000, bm_000, bn_000, bo_000, bp_000, bq_000, br_000, bs_000, bt_000, bu_000, bv_000, bx_000, by_000, bz_000, ca_000, cb_000, cc_000, cd_000, ce_000, cf_000, cg_000, ch_000, ci_000, cj_000, ck_000, cl_000, cm_000, ...]
# Index: []

# %%
# df1.isna().sum()

# %% [markdown]
# ## 1.5 Checking Duplicated Features

# %%
#Check duplicated rows in train
feature_duplicated_train = df1.T.drop_duplicates().T

# %%
df1.shape
# Out:
# (60000, 171)

# %%
feature_duplicated_train.shape
# Out:
# (60000, 171)

# %% [markdown]
# OK.

# %% [markdown]
# ## 1.6 Replace / Fill NA

# %%
df1 = df1.replace(np.nan,0)

# %% [markdown]
# ## 1.7 Descriptive Statistics

# %%
num_attributes = df1.select_dtypes(include=['float64'])

# %%
num_attributes.head()
# Out:
#       aa_000  ab_000          ac_000   ad_000  ae_000  af_000  ag_000  ag_001  ag_002   ag_003     ag_004       ag_005       ag_006       ag_007     ag_008  ag_009       ah_000  ai_000   aj_000  ak_000   al_000      am_0       an_000       ao_000       ap_000       aq_000  ar_000  as_000  at_000  au_000    av_000   ax_000  ay_000  ay_001  ay_002  ay_003     ay_004      ay_005       ay_006       ay_007       ay_008  ay_009    az_000    az_001     az_002     az_003       az_004       az_005     az_006    az_007  az_008  az_009       ba_000       ba_001      ba_002      ba_003      ba_004      ba_005       ba_006      ba_007     ba_008    ba_009       bb_000   bc_000   bd_000   be_000   bf_000       bg_000     bh_000      bi_000      bj_000      bk_000      bl_000      bm_000      bn_000      bo_000  bp_000  bq_000  br_000      bs_000     bt_000       bu_000       bv_000       bx_000     by_000      bz_000      ca_000      cb_000       cc_000       cd_000      ce_000  cf_000   cg_000  ch_000       ci_000  cj_000      ck_000  cl_000    cm_000  cn_000  cn_001    cn_002      cn_003       cn_004       cn_005       cn_006     cn_007     cn_008    cn_009   co_000   cp_000       cq_000  cr_000     cs_000    cs_001      cs_002      cs_003      cs_004       cs_005       cs_006     cs_007   cs_008  cs_009    ct_000    cu_000       cv_000      cx_000  cy_000      cz_000  da_000  db_000       dc_000    dd_000    de_000  df_000  dg_000  dh_000  di_000  dj_000  dk_000  dl_000  dm_000     dn_000     do_000     dp_000    dq_000   dr_000      ds_000     dt_000        du_000       dv_000     dx_000     dy_000  dz_000  ea_000        eb_000     ec_00    ed_000      ee_000       ee_001       ee_002      ee_003      ee_004      ee_005      ee_006      ee_007      ee_008    ee_009  ef_000  eg_000
# 0 76698.0000  0.0000 2130706438.0000 280.0000  0.0000  0.0000  0.0000  0.0000  0.0000   0.0000 37250.0000 1432864.0000 3664156.0000 1007684.0000 25896.0000  0.0000 2551696.0000  0.0000   0.0000  0.0000   0.0000    0.0000 4933296.0000 3655166.0000 1766008.0000 1132040.0000  0.0000  0.0000  0.0000  0.0000 1012.0000 268.0000  0.0000  0.0000  0.0000
#             aa_000     ab_000          ac_000          ad_000     ae_000     af_000       ag_000       ag_001        ag_002        ag_003         ag_004         ag_005        ag_006        ag_007        ag_008        ag_009        ah_000        ai_000       aj_000        ak_000        al_000          am_0         an_000         ao_000        ap_000        aq_000     ar_000       as_000        at_000       au_000      av_000      ax_000        ay_000        ay_001        ay_002        ay_003        ay_004         ay_005         ay_006         ay_007         ay_008        ay_009        az_000       az_001        az_002        az_003         az_004         az_005        az_006        az_007       az_008      az_009         ba_000         ba_001        ba_002        ba_003        ba_004        ba_005        ba_006        ba_007        ba_008        ba_009         bb_000      bc_000      bd_000      be_000     bf_000        bg_000       bh_000        bi_000        bj_000       bk_000       bl_000       bm_000       bn_000       bo_000       bp_000       bq_000       br_000       bs_000       bt_000         bu_000         bv_000         bx_000       by_000        bz_000      ca_000       cb_000         cc_000       cd_000       ce_000          cf_000     cg_000     ch_000         ci_000        cj_000        ck_000      cl_000     cm_000       cn_000        cn_001        cn_002        cn_003         cn_004         cn_005        cn_006        cn_007       cn_008        cn_009          co_000      cp_000         cq_000     cr_000      cs_000      cs_001        cs_002        cs_003        cs_004         cs_005        cs_006        cs_007       cs_008        cs_009      ct_000      cu_000        cv_000        cx_000      cy_000        cz_000     da_000     db_000         dc_000      dd_000      de_000        df_000        dg_000         dh_000        di_000      dj_000       dk_000         dl_000        dm_000       dn_000       do_000      dp_000          dq_000        dr_000       ds_000      dt_000         du_000         dv_000         dx_000       dy_000     dz_000     ea_000          eb_000       ec_00     ed_000        ee_000        ee_001        ee_002        ee_003        ee_004        ee_005        ee_006         ee_007        ee_008       ee_009     ef_000     eg_000
# count   60000.0000 60000.0000      60000.0000      60000.0000 60000.0000 60000.0000   60000.0000   60000.0000    60000.0000    60000.0000     60000.0000     60000.0000    60000.0000    60000.0000    60000.0000    60000.0000    60000.0000    60000.0000   60000.0000    60000.0000    60000.0000    60000.0000     60000.0000     60000.0000    60000.0000    60000.0000 60000.0000   60000.0000    60000.0000   60000.0000  60000.0000  60000.0000    60000.0000    60000.0000    60000.0000    60000.0000    60000.0000     60000.0000     60000.0000     60000.0000     60000.0000    60000.0000    60000.0000   60000.0000    60000.0000    60000.0000     60000.0000     60000.0000    60000.0000    60000.0000   60000.0000  60000.0000     60000.0000     60000.0000    60000.0000    60000.0000    60000.0000    60000.0000    60000.0000    60000.0000    60000.0000    60000.0000     60000.0000  60000.0000  60000.0000  60000.0000 60000.0000    60000.0000   60000.0000    60000.0000    60000.0000   60000.0000   60000.0000   60000.0000   60000.0000   60000.0000   60000.0000   60000.0000   60000.0000   60000.0000   60000.0000     60000.0000     60000.0000     60000.0000   60000.0000    60000.0000  60000.0000   60000.0000     60000.0000   60000.0000   60000.0000      60000.0000 60000.0000 60000.0000     60000.0000    60000.0000    60000.0000  60000.0000 60000.0000   60000.0000    60000.0000    60000.0000    60000.0000     60000.0000     60000.0000    60000.0000    60000.0000   60000.0000    60000.0000      60000.0000  60000.0000     60000.0000 60000.0000  60000.0000  60000.0000    60000.0000    60000.0000    60000.0000     60000.0000    60000.0000    60000.0000   60000.0000    60000.0000  60000.0000  60000.0000    60000.0000    60000.0000  60000.0000    60000.0000 60000.0000 60000.0000     60000.0000  60000.0000  60000.0000    60000.0000    60000.0000     60000.0000    60000.0000  60000.0000   60000.0000     60000.0000    60000.0000   60000.0000   60000.0000  60000.0000      60000.0000    60000.0000   60000.0000  60000.0000     60000.0000     60000.0000     60000.0000   60000.0000 60000.0000 60000.0000      60000.0000  60000.0000 60000.0000    60000.0000    60000.0000    60000.0000    60000.0000    60000.0000    60000.0000    60000.0000     60000.0000    60000.0000   60000.0000 60000.0000 60000.0000
 18824656.0000 10124620.0000 4530258.0000 14217662.0000 45584242.0000 123047106.0000 467832334.0000 64589140.0000 39158218.0000 1947884.0000 666148.0000 232871714.0000 116283282.0000 55807388.0000 36931418.0000 25158556.0000 19208664.0000 18997660.0000 14314086.0000 31265984.0000 43706408.0000 192871534.0000 396952.0000 306452.0000 810568.0000 51050.0000 74247318.0000 3200582.0000 44937496.0000 45736316.0000 1310700.0000 1310700.0000 1310700.0000 1310700.0000 1310700.0000 1310700.0000 1310700.0000 1310700.0000 1037240.0000 2746564.8300 192871534.0000 192871534.0000 186353854.0000 1002003.0000 40542588.0000 120956.0000 1209520.0000 148615188.0000 1209600.0000 4908098.0000 8584297736.0000 21400.0000     2.0000 140986129.9200 60949671.3600 55428669.1200 130560.0000 73370.0000 6278490.0000 14512994.0000 58508606.0000 94979324.0000 169869316.0000 117815764.0000 72080406.0000 33143734.0000 7541716.0000 36398374.0000 8584297742.0000 496360.0000 192871534.0000 57450.0000 839240.0000 438806.0000 46085940.0000 42421854.0000 74860628.0000 379142116.0000 73741974.0000 12884218.0000 1584558.0000 44902992.0000 910366.0000 733688.0000 81610510.0000 44105494.0000 931472.0000 19156530.0000 21006.0000  9636.0000 120759484.0000 445142.0000 176176.0000 21613910.0000 27064294.0000 124700880.0000 22987424.0000 726750.0000 5483574.0000 103858120.0000 23697916.0000 2924584.0000 1874542.0000 348118.0000 6351872864.0000 50137662.0000 4970962.0000 656432.0000 460207620.0000 127034534.0000 114288420.0000 3793022.0000  1414.0000  8506.0000 1322456920.0000 106020.2200 82806.0000 74984446.0000 98224378.0000 77933926.0000 37758390.0000 97152378.0000 57435236.0000 31607814.0000 119580108.0000 19267396.0000 3810078.0000   482.0000  1146.0000

# %%
# Central Tendency - Media, Mediana 
ct1 = pd.DataFrame(num_attributes.apply(np.mean)).T
ct2 = pd.DataFrame(num_attributes.apply(np.median)).T

# Dispersion std, min, max, range,skew,kurtosis
d1 = pd.DataFrame(num_attributes.apply(np.std)).T
d2 = pd.DataFrame(num_attributes.apply(min)).T
d3 = pd.DataFrame(num_attributes.apply(max)).T
d4 = pd.DataFrame(num_attributes.apply(lambda x: x.max() - x.min())).T
d5 = pd.DataFrame(num_attributes.apply(lambda x: x.skew())).T
d6 = pd.DataFrame(num_attributes.apply(lambda x: x.kurtosis())).T

# %%
# Concatenate
m = pd.concat([d2,d3,d4,ct1,ct2,d1,d5,d6]).T.reset_index()
m.columns=['attributes','min','max','range','mean','median','std','skew','kurtosis']

# %%
m.head()
# Out:
#   attributes    min             max           range           mean     median            std     skew   kurtosis
# 0     aa_000 0.0000    2746564.0000    2746564.0000     59336.4996 30776.0000    145428.8446   6.1158    48.2974
# 1     ab_000 0.0000        204.0000        204.0000         0.1625     0.0000         1.6873  57.0362  5119.1661
# 2     ac_000 0.0000 2130706796.0000 2130706796.0000 336225803.5780   120.0000 776756070.8145   1.8774     1.5247
# 3     ad_000 0.0000 8584297742.0000 8584297742.0000    143407.0840    42.0000  35044955.4882 244.9490 59999.9992
# 4     ae_000 0.0000      21050.0000      21050.0000         6.5350     0.0000       158.1466  92.5316 11228.4059

# %% [markdown]
# # 2.0 Feature Engineering

# %%
df2 = df1.copy()

# %% [markdown]
# # 3.0 Variables Filtering

# %%
df3 = df2.copy()

# %% [markdown]
# # 4.0 EDA

# %%
df4 = df3.copy()

# %% [markdown]
# ## 4.1 Univariate Analysis

# %% [markdown]
# ### 4.1.1 Response Variable

# %%
df4['class'] = df4['class'].apply(lambda x: 1 if x == 'pos' else 0)

# %%
sns.displot(df4['class'],kde=False);

# %%
df4['class'].value_counts()
# Out:
# 0    59000
# 1     1000
# Name: class, dtype: int64

# %%
distri = df4['class'].value_counts(normalize=True) 
color = ['gray','orange']
plt.bar(x=distri.index,height=distri,color=color)
plt.xticks([0,1],['neg','pos'])
plt.ylabel('Porcentage(%) ');

# %%
distri
# Out:
# 0   0.9833
# 1   0.0167
# Name: class, dtype: float64

# %% [markdown]
# - 59000 caminhões com outros tipos de manutenção. (98%)
# - 1000 caminhões com manutenção de sistema de ar. (2%)
#
# -> Classes muito desbalanceadas, nos próximos ciclos iremos testar algumas técnicas de amostragem.

# %% [markdown]
# ## 4.1.2 Numerical Variables

# %% [markdown]
# Como observamos no ciclo anterior as variáveis estão anonimizados portanto fica mais difícil de extrair algum Insight dos dados em si. Conseguimos ver também que a distribuição tende muito a 0, não tendo uma distribuição normal.

# %% [markdown]
# # 5.0 Data Preparation

# %%
df5 = df4.copy()

# %%
X = df4.drop('class',axis=1)
y = df4['class'].copy()

# %%
x_train, x_validation, y_train, y_validation = ms.train_test_split(X,y,test_size=0.20,random_state=42)

# %% [markdown]
# ## 5.1 Rescaling Features

# %% [markdown]
# Devido a grande variabilidade dos valores das features, nós iremos então realizar uma padronização dos dados utilizando o StandardScaler da biblioteca do sklearn. A escala é essencial para algoritmos de machine learning possam calcular a distçancia entre os dados

# %%
# mm = pp.MinMaxScaler()
ss = pp.StandardScaler()

# %%
ss.fit(x_train)

# USING STANDARD SCALAR
x_train_ss = ss.transform(x_train)
x_val_ss = ss.transform(x_validation)

x_train = pd.DataFrame(x_train_ss,columns=x_train.columns)
x_validation = pd.DataFrame(x_val_ss,columns=x_validation.columns)

# %%
# # USING MINMAX
# x_train_mm = mm.fit_transform(x_train)
# x_val_mm = mm.transform(x_validation)

# x_train = pd.DataFrame(x_train_mm,columns=x_train.columns)
# x_validation = pd.DataFrame(x_val_mm,columns=x_validation.columns)

# %% [markdown]
# # 6.0 Feature Selection

# %%
df6 = df5.copy()

# %% [markdown]
# # 7.0 Machine Learning Model

# %% [markdown]
# * Nessa seção iremos utilizar outros algoritmos de modelagem para avaliar sua perfomance. Uma função chamada cross_validation também foi criada para podemos medir a perfomance de cada modelo de forma mais segura (evitar overfitting).
#
# * O cross_validation é um método estatístico de avaliação e comparação de algoritmos de aprendizado dividindo os dados em dois segmentos: um usado para treinar o modelo e outro para validar os resultados do modelo. -> Abordagem de Folds

# %% [markdown]
# ## 7.1 KNN Baseline

# %%
# - O algoritmo de Machine Learning que será utilizado como modelo baseline será o KNN (K-Nearest Neighbors, ou K-vizinhos mais próximos). 
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(x_train,y_train)

classification_metrics(knn,x_validation,y_validation)
# Out:
#              Model_Name  Recall  F1_Score  PRC AUC  AUC SCORE
# 0  KNeighborsClassifier  0.5236    0.6325   0.6510     0.9160

# %% [markdown]
# ### 7.1.1  KNN Cross Validation

# %%
knn_cv = cross_validation(knn,x_train,y_train,5,Verbose=False)

# %% [markdown]
# ## 7.2 Logistic Regression

# %%
lr = LogisticRegression() 
lr.fit(x_train,y_train)
classification_metrics(lr,x_validation,y_validation)
# Out:
# /home/jordan/Estudismo/case_bix/case_tecnico/venv_truck/.venv/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#            Model_Name  Recall  F1_Score  PRC AUC  AUC SCORE
# 0  LogisticRegression  0.6698    0.7208   0.7547     0.9653

# %% [markdown]
# ### 7.2.1 Logistic Regression Cross Validation

# %%
lr_cv = cross_validation(lr,x_train,y_train,5,Verbose=False)
# Out:
# /home/jordan/Estudismo/case_bix/case_tecnico/venv_truck/.venv/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jordan/Estudismo/case_bix/case_tecnico/venv_truck/.venv/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jordan/Estudismo/case_bix/case_tecnico/venv_truck/.venv/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jordan/Estudismo/case_bix/case_tecnico/venv_truck/.venv/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jordan/Estudismo/case_bix/case_tecnico/venv_truck/.venv/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# ## 7.3 Random Forest Classifier

# %%
rf = RandomForestClassifier()
rf.fit(x_train,y_train)
classification_metrics(rf,x_validation,y_validation)
# Out:
#                Model_Name  Recall  F1_Score  PRC AUC  AUC SCORE
# 0  RandomForestClassifier  0.6745    0.7730   0.8622     0.9835

# %% [markdown]
# ### 7.3.1 Random Forest CV

# %%
rf_cv = cross_validation(rf,x_train,y_train,5,Verbose=False)

# %% [markdown]
# ## 7.4 LGBM Classifier

# %%
lgbm = LGBMClassifier()
lgbm.fit(x_train,y_train)
classification_metrics(lgbm,x_validation,y_validation)
# Out:
#        Model_Name  Recall  F1_Score  PRC AUC  AUC SCORE
# 0  LGBMClassifier  0.7217    0.7866   0.8675     0.9879

# %% [markdown]
# ### 7.4.1 LGBM Cross-Validation

# %%
lgbm_cv = cross_validation(lgbm,x_train,y_train,5,Verbose=False)

# %% [markdown]
# ## 7.5 XGBoost Classifier

# %%
xgboost = XGBClassifier()
xgboost.fit(x_train,y_train)
classification_metrics(xgboost,x_validation,y_validation)
# Out:
#       Model_Name  Recall  F1_Score  PRC AUC  AUC SCORE
# 0  XGBClassifier  0.7264    0.7918   0.8782     0.9846

# %%
xgb_cv = cross_validation(xgboost,x_train,y_train,5,Verbose=False)

# %% [markdown]
# ## 7.6 Compare Model Perfomance

# %% [markdown]
# ### 7.6.1 Real Perfomance - Cross Validation

# %%
model_results_cv = pd.concat([knn_cv,lr_cv,rf_cv,lgbm_cv,xgb_cv]) 
model_results_cv.sort_values('AUC PR',ascending=False)
# Out:
#                Model Name  Recall  ROC AUC  AUC PR  F1 Score
# 0           XGBClassifier  0.7335   0.9908  0.8844    0.8028
# 0          LGBMClassifier  0.7043   0.9911  0.8673    0.7805
# 0  RandomForestClassifier  0.6866   0.9856  0.8673    0.7789
# 0      LogisticRegression  0.6523   0.9688  0.7607    0.7088
# 0    KNeighborsClassifier  0.5114   0.9038  0.6342    0.6225

# %% [markdown]
# Nós utilizaremos a métrica ***AUC PR*** para medir a perfomance do modelo como um todo, portanto o algoritmo escolhido baseado na perfomanec foi o XGBoost Classifier.

# %% [markdown]
# # 8.0 Hyper Parameter Fine Tuning

# %% [markdown]
# # 9.0 Final Model - Testing XGBoostClassifier

# %% [markdown]
# ## 9.1 Test Dataset Transformation

# %%
df_test = pd.read_csv('../data/air_system_present_year.csv')
df_test = df_test.replace('na','0')
df_test = df_test.astype({col: float for col in df1.columns[1:]})
df_test['class'] = df_test['class'].apply(lambda x: 1 if x == 'pos' else 0)

# %%
x_test = df_test.drop(['class'],axis=1)
y_test = df_test['class']

# %% [markdown]
# StandarScaler on the test dataset

# %%
x_test_scaler = ss.transform(x_test)
x_test_final = pd.DataFrame(x_test_scaler,columns=x_test.columns)
x_test_final.head()
# Out:
#    aa_000  ab_000  ac_000  ad_000  ae_000  af_000  ag_000  ag_001  ag_002  ag_003  ag_004  ag_005  ag_006  ag_007  ag_008  ag_009  ah_000  ai_000  aj_000  ak_000  al_000    am_0  an_000  ao_000  ap_000  aq_000  ar_000  as_000  at_000  au_000  av_000  ax_000  ay_000  ay_001  ay_002  ay_003  ay_004  ay_005  ay_006  ay_007  ay_008  ay_009  az_000  az_001  az_002  az_003  az_004  az_005  az_006  az_007  az_008  az_009  ba_000  ba_001  ba_002  ba_003  ba_004  ba_005  ba_006  ba_007  ba_008  ba_009  bb_000  bc_000  bd_000  be_000  bf_000  bg_000  bh_000  bi_000  bj_000  bk_000  bl_000  bm_000  bn_000  bo_000  bp_000  bq_000  br_000  bs_000  bt_000  bu_000  bv_000  bx_000  by_000  bz_000  ca_000  cb_000  cc_000  cd_000  ce_000  cf_000  cg_000  ch_000  ci_000  cj_000  ck_000  cl_000  cm_000  cn_000  cn_001  cn_002  cn_003  cn_004  cn_005  cn_006  cn_007  cn_008  cn_009  co_000  cp_000  cq_000  cr_000  cs_000  cs_001  cs_002  cs_003  cs_004  cs_005  cs_006  cs_007  cs_008  cs_009  ct_000  cu_000  cv_000  cx_000  cy_000  cz_000  da_000  db_000  dc_000  dd_000  de_000  df_000  dg_000  dh_000  di_000  dj_000  dk_000  dl_000  dm_000  dn_000  do_000  dp_000  dq_000  dr_000  ds_000  dt_000  du_000  dv_000  dx_000  dy_000  dz_000  ea_000  eb_000   ec_00  ed_000  ee_000  ee_001  ee_002  ee_003  ee_004  ee_005  ee_006  ee_007  ee_008  ee_009  ef_000  eg_000
 -0.0229 -0.0754 -0.0330 -0.1532 -0.4353 -0.3091 -0.1867 -0.0179 -0.0254 -0.0079 -0.0853 -0.0093 -0.0265 -0.0253 -0.0271 -0.3364 -0.4496 -0.4770 -0.0451 -0.1446 -0.4121 -0.4330 -0.3395 -0.2764 -0.1814 -0.1294 -0.0181 -0.0272 -0.1990 -0.3081 -0.3537 -0.2921 -0.2945 -0.3692 -0.3708 -0.3555 -0.3013 -0.3059 -0.1941 -0.3095 -0.1911 -0.0207 -0.0233

# %% [markdown]
# ## 9.2 Dataset Preparation

# %%
x_train_final = pd.concat([x_train,x_validation],axis=0)
y_train_final = pd.concat([y_train,y_validation],axis=0)

# %% [markdown]
# ## 9.3 XGBoost Model Applied

# %%
xgboost = XGBClassifier()
xgboost.fit(x_train_final,y_train_final)

yhat_xgboost = xgboost.predict(x_test_final)
yhat_xgboost_proba =  xgboost.predict_proba(x_test_final)

recall = recall_score(y_test, yhat_xgboost)
auc_pr = average_precision_score(y_test,yhat_xgboost_proba[:,1])

print('Para nosso modelo XGBoost, temos então um recall de {:.2f} e AUC PR de {:.2f}'.format(recall,auc_pr))
# Out:
# Para nosso modelo XGBoost, temos então um recall de 0.79 e AUC PR de 0.93

# %%
cm = confusion_matrix(y_test, yhat_xgboost, labels=xgboost.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=xgboost.classes_)

disp.plot()

# %% [markdown]
# # 10. Business Results

# %% [markdown]
# Para o modelo XGBoost Classifier com Padronização dos dados temos os seguintes resultos de negócio:
#
# Da frota de 16 mil caminhões:
# * 15610 não apresentam problemas no sistema de ar e nosso modelo acertou -> Logo o custo é de 10x, valor total: $156.100,00
#
# * 77 apresentavam problemas no sistema de ar mas nosso modelo errou > Logo o custo é de 500x , valor total: $38.500.
#
# * 15 não apresentam problemas no sistema de ar e nosso modelo errou -> Logo o custo é de 10x, valor total: $150.
#
# * 298 apresentaram problemas no sistema de ar e o nosso modelo acertou -> Logo o custo é 25x, valor total: $7450.

# %%
Custo = (77*500)+(298*25)
Custo
# Out:
# 45950

# %% [markdown]
# Como queremos diminuir os custos do sistema de ar na frota de caminhões, iremos analisar somente somente as classes positivas reais(1), que mostram a quantidade de caminhões com problema no sistema de ar da base de dados no ano presente e custo gerado pelo nosso modelo.

# %%
df_impacto = pd.DataFrame({ 'Tipo'   : ['Modelo_Baseline_KNN','Modelo XGBoost','META'],
                            'Custo($)' : [109125,45950,37000]})

# %%
sns.barplot(x='Tipo',y='Custo($)',data=df_impacto);

# %%
df_impacto
# Out:
#                   Tipo  Custo($)
# 0  Modelo_Baseline_KNN    109125
# 1       Modelo XGBoost     45950
# 2                 META     37000

# %% [markdown]
# ## Conclusão Ciclo 02
# * Como podemos observar nas tabelas e gráficos, esse ciclo teve um grande salto com relação ao custo final obtido se comparado com o nosso modelo Baseline.

# %% [markdown]
# # Atividades para o próximo ciclo

# %% [markdown]
# * Estudo do espaço de dados
# * Redução do espaço de dados utilizando PCA ( Principal Component Analysis)
# * Analisar a perfomance e resultados de negócio do modelo PCA.
